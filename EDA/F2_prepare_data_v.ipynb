# %% [markdown]
# # Run the scripts within VIB_10xmultiome_2_WS3000F folder  first
# Particularly, run VIB_10xmultiome_2_WS3000F/_ArchR_TSS/prepare_frag_for_archr.sh

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D 
from matplotlib import gridspec
import matplotlib.colors as colors


import os
import seaborn as sns

# %% [markdown]
# ## Load RNA cell Barcodes from RNA-only modality CR analysis

# %%
entropy_dir ='/mnt/hdd_bob/syy/adipose/atac/res/VIB_10xmultiome_2_WS3000F/'

entropy_all_file = os.path.join(entropy_dir, 'calculated_barcode_entropy_wDebrisflag_df.tsv')
entropy_df = pd.read_csv(entropy_all_file, sep=',', index_col=0)
entropy_df['atac_bc'] = entropy_df.index.str.split('-').str[0]
print(entropy_df.shape) 
entropy_df.head(2)
# Out:
# (33287, 8)
#                      Entropy  Entropy_open_region  Mp  mle_lambda  \
# AAGCCATAGCTAATAG-1  0.005725             1.069145  11    0.343957
# CACGGTAAGAATCACA-1  0.004039             1.910865  19    1.377521
#
#                     P0_open_region  P_closed_state DNA_debris  \
# AAGCCATAGCTAATAG-1        0.708959        0.999545         NO
# CACGGTAAGAATCACA-1        0.252203        0.999694         NO
#
#                              atac_bc
# AAGCCATAGCTAATAG-1  AAGCCATAGCTAATAG
# CACGGTAAGAATCACA-1  CACGGTAAGAATCACA

# %%
# Load filtered barcodes from each filtering method
sade_bcs= os.path.join(entropy_dir, 'entropy_filtered_bc_df.tsv')
cr_bcs = os.path.join(entropy_dir, '_CR_FRIP', 'barcodes.tsv')
tss_bcs = os.path.join(entropy_dir, '_ArchR_TSS', 'QualityControl/VIB_10xmultiome_2_Metadata.tsv')

sade_bc_df = pd.read_csv(sade_bcs, sep=',', index_col=0)
cr_bcs_df = pd.read_csv(cr_bcs, sep='\t', index_col=0, header=None)
cr_bcs_df.index.name = 'atac_barcodes'
_tss_bcs_df = pd.read_csv(tss_bcs, sep='\t', index_col=0)
_tss_bcs_df['atac_barcodes'] = _tss_bcs_df.index.map(lambda x: x.split('#')[1])
tss_bcs_df = _tss_bcs_df.loc[_tss_bcs_df['Keep'] == 1].copy()

# %%
tss_bcs_df.head(2)
# Out:
#                                       nFrags  nMonoFrags  nDiFrags  \
# cellNames
# VIB_10xmultiome_2#GGGTTGCAGCTCAAGG-1   93652       47018     37344
# VIB_10xmultiome_2#GTCATTTAGAGAGCAA-1   92024       24025     55290
#
#                                       nMultiFrags  TSSEnrichment  ReadsInTSS  \
# cellNames
# VIB_10xmultiome_2#GGGTTGCAGCTCAAGG-1         9290         20.827       61970
# VIB_10xmultiome_2#GTCATTTAGAGAGCAA-1        12709         12.683       17927
#
#                                       Keep  ReadsInPromoter  PromoterRatio  \
# cellNames
# VIB_10xmultiome_2#GGGTTGCAGCTCAAGG-1     1            55796       0.297890
# VIB_10xmultiome_2#GTCATTTAGAGAGCAA-1     1            17285       0.093916
#
#                                       ReadsInBlacklist  BlacklistRatio  \
# cellNames
# VIB_10xmultiome_2#GGGTTGCAGCTCAAGG-1              1417        0.007565
# VIB_10xmultiome_2#GTCATTTAGAGAGCAA-1               839        0.004559
#
#                                            atac_barcodes
# cellNames
# VIB_10xmultiome_2#GGGTTGCAGCTCAAGG-1  GGGTTGCAGCTCAAGG-1
# VIB_10xmultiome_2#GTCATTTAGAGAGCAA-1  GTCATTTAGAGAGCAA-1

# %%
tss_bcs_df
# Out:
#                                       nFrags  nMonoFrags  nDiFrags  \
# cellNames
# VIB_10xmultiome_2#GGGTTGCAGCTCAAGG-1   93652       47018     37344
# VIB_10xmultiome_2#GTCATTTAGAGAGCAA-1   92024       24025     55290
# VIB_10xmultiome_2#AAAGCCTAGGATTATG-1   76499       44716     25339
# VIB_10xmultiome_2#TATTGTGGTGGATTAG-1   60195       32781     21972
# VIB_10xmultiome_2#TCAAGTGCACGCAATA-1   60116       33088     22982
# ...                                      ...         ...       ...
# VIB_10xmultiome_2#TGCTCAATCACAATAG-1    1005         403       531
# VIB_10xmultiome_2#CTTCACTTCCGCTAAC-1    1003         394       531
# VIB_10xmultiome_2#GGGACAACATGAGCCG-1    1003         329       616
# VIB_10xmultiome_2#GATCCTTCATTGAGAT-1    1002         681       253
# VIB_10xmultiome_2#GGGCAATGTTGTGACT-1    1000         577       334
#
#                                       nMultiFrags  TSSEnrichment  ReadsInTSS  \
# cellNames
# VIB_10xmultiome_2#GGGTTGCAGCTCAAGG-1         9290         20.827       61970
# VIB_10xmultiome_2#GTCATTTAGAGAGCAA-1        12709         12.683       17927
# VIB_10xmultiome_2#AAAGCCTAGGATTATG-1         6444         19.119       57719
# VIB_10xmultiome_2#TATTGTGGTGGATTAG-1         5442         19.352       42150
# VIB_10xmultiome_2#TCAAGTGCACGCAATA-1         4046         11.516       19227
# ...                                           ...            ...         ...
# VIB_10xmultiome_2#TGCTCAATCACAATAG-1           71         13.771         153
# VIB_10xmultiome_2#CTTCACTTCCGCTAAC-1           78          6.485         131
# VIB_10xmultiome_2#GGGACAACATGAGCCG-1           58          4.752          48
# VIB_10xmultiome_2#GATCCTTCATTGAGAT-1           68         20.950         730
# VIB_10xmultiome_2#GGGCAATGTTGTGACT-1           89         17.509         672
#
#                                       Keep  ReadsInPromoter  PromoterRatio  \
# cellNames
# VIB_10xmultiome_2#GGGTTGCAGCTCAAGG-1     1            55796       0.297890
# VIB_10xmultiome_2#GTCATTTAGAGAGCAA-1     1            17285       0.093916
# VIB_10xmultiome_2#AAAGCCTAGGATTATG-1     1            51750       0.338240
# VIB_10xmultiome_2#TATTGTGGTGGATTAG-1     1            37027       0.307559
# VIB_10xmultiome_2#TCAAGTGCACGCAATA-1     1            19280       0.160357
# ...                                    ...              ...            ...
# VIB_10xmultiome_2#TGCTCAATCACAATAG-1     1              152       0.075622
# VIB_10xmultiome_2#CTTCACTTCCGCTAAC-1     1              133       0.066301
# VIB_10xmultiome_2#GGGACAACATGAGCCG-1     1               26       0.012961
# VIB_10xmultiome_2#GATCCTTCATTGAGAT-1     1              750       0.374251
# VIB_10xmultiome_2#GGGCAATGTTGTGACT-1     1              635       0.317500
#
#                                       ReadsInBlacklist  BlacklistRatio  \
# cellNames
# VIB_10xmultiome_2#GGGTTGCAGCTCAAGG-1              1417        0.007565
# VIB_10xmultiome_2#GTCATTTAGAGAGCAA-1               839        0.004559
# VIB_10xmultiome_2#AAAGCCTAGGATTATG-1               971        0.006346
# VIB_10xmultiome_2#TATTGTGGTGGATTAG-1               763        0.006338
# VIB_10xmultiome_2#TCAAGTGCACGCAATA-1              1398        0.011628
# ...                                                ...             ...
# VIB_10xmultiome_2#TGCTCAATCACAATAG-1                64        0.031841
# VIB_10xmultiome_2#CTTCACTTCCGCTAAC-1                 4        0.001994
# VIB_10xmultiome_2#GGGACAACATGAGCCG-1                 0        0.000000
# VIB_10xmultiome_2#GATCCTTCATTGAGAT-1                 6        0.002994
# VIB_10xmultiome_2#GGGCAATGTTGTGACT-1                 8        0.004000
#
#                                            atac_barcodes
# cellNames
# VIB_10xmultiome_2#GGGTTGCAGCTCAAGG-1  GGGTTGCAGCTCAAGG-1
# VIB_10xmultiome_2#GTCATTTAGAGAGCAA-1  GTCATTTAGAGAGCAA-1
# VIB_10xmultiome_2#AAAGCCTAGGATTATG-1  AAAGCCTAGGATTATG-1
# VIB_10xmultiome_2#TATTGTGGTGGATTAG-1  TATTGTGGTGGATTAG-1
# VIB_10xmultiome_2#TCAAGTGCACGCAATA-1  TCAAGTGCACGCAATA-1
# ...                                                  ...
# VIB_10xmultiome_2#TGCTCAATCACAATAG-1  TGCTCAATCACAATAG-1
# VIB_10xmultiome_2#CTTCACTTCCGCTAAC-1  CTTCACTTCCGCTAAC-1
# VIB_10xmultiome_2#GGGACAACATGAGCCG-1  GGGACAACATGAGCCG-1
# VIB_10xmultiome_2#GATCCTTCATTGAGAT-1  GATCCTTCATTGAGAT-1
# VIB_10xmultiome_2#GGGCAATGTTGTGACT-1  GGGCAATGTTGTGACT-1
#
# [2132 rows x 12 columns]

# %%
# create union cell set by combining three filtering sets
Union_cell_subdir = os.path.join(entropy_dir, '_cell_calling_comparison')
os.mkdir(Union_cell_subdir) if not os.path.exists(Union_cell_subdir) else None
tosave_union_cell_set = os.path.join(Union_cell_subdir, 'Union_cell_3set_all_info.tsv')


# Load fragments file
frag_file = os.path.join(entropy_dir, 'fragments.tsv')
frag = pd.read_csv(frag_file, sep='\t', index_col=3, header=None)
frag.index.name ='atac_bc'
frag.columns = ['chrom', 'start', 'end', 'support']
frag['atac_barcodes'] = frag.index
      

total_frag = frag.groupby('atac_barcodes').size().rename('total_fragments')
total_frag_df = total_frag.to_frame()


total_frag_df['atac_pass_CR'] = total_frag_df.index.isin(cr_bcs_df.index)
total_frag_df['atac_pass_entropy'] = total_frag_df.index.isin(sade_bc_df.index)
total_frag_df['atac_pass_archr_TSS'] = total_frag_df.index.isin(tss_bcs_df['atac_barcodes'])


total_frag_df['_2set_identified_by_atac_SC'] = total_frag_df.apply(lambda row: 'both' if row['atac_pass_CR'] and row['atac_pass_entropy'] else ('entropy_only' if row['atac_pass_entropy'] else ('cr_only' if row['atac_pass_CR'] else ('entropy_only' if row['atac_pass_entropy'] else 'none'))), axis=1)
total_frag_df['_2set_identified_by_atac_ST'] = total_frag_df.apply(lambda row: 'both' if row['atac_pass_archr_TSS'] and row['atac_pass_entropy'] else ('tss_only' if row['atac_pass_archr_TSS'] else ('entropy_only' if row['atac_pass_entropy']  else 'none')), axis=1)


total_frag_df.loc[total_frag_df['atac_pass_CR'] & total_frag_df['atac_pass_entropy'] & total_frag_df['atac_pass_archr_TSS'],'_3set_identified_by_atac'] = 'common'
total_frag_df.loc[total_frag_df['atac_pass_CR'] & total_frag_df['atac_pass_entropy'] & ~total_frag_df['atac_pass_archr_TSS'],'_3set_identified_by_atac'] = 'SADE+CR, not TSS'
total_frag_df.loc[~total_frag_df['atac_pass_CR'] & total_frag_df['atac_pass_entropy'] & total_frag_df['atac_pass_archr_TSS'],'_3set_identified_by_atac'] = 'SADE+TSS, not CR'
total_frag_df.loc[total_frag_df['atac_pass_CR'] & ~total_frag_df['atac_pass_entropy'] & total_frag_df['atac_pass_archr_TSS'],'_3set_identified_by_atac'] = 'CR+TSS, not SADE'  
total_frag_df.loc[total_frag_df['atac_pass_entropy'] & ~total_frag_df['atac_pass_CR'] & ~total_frag_df['atac_pass_archr_TSS'],'_3set_identified_by_atac'] = 'SADE unique'
total_frag_df.loc[total_frag_df['atac_pass_CR'] & ~total_frag_df['atac_pass_entropy'] & ~total_frag_df['atac_pass_archr_TSS'],'_3set_identified_by_atac'] = 'CR unique'
total_frag_df.loc[~total_frag_df['atac_pass_CR'] & ~total_frag_df['atac_pass_entropy'] & total_frag_df['atac_pass_archr_TSS'],'_3set_identified_by_atac'] = 'TSS unique'
total_frag_df.loc[~total_frag_df['atac_pass_CR'] & ~total_frag_df['atac_pass_entropy'] & ~total_frag_df['atac_pass_archr_TSS'],'_3set_identified_by_atac'] = 'none'

for col in ['Entropy', 'DNA_debris', 'P_closed_state']:
    total_frag_df[col] = total_frag_df.index.map(lambda x: entropy_df.loc[x, col] if x in entropy_df.index else np.nan)

total_frag_df.to_csv(tosave_union_cell_set, sep='\t')

# %%
total_frag_df.head(2)
# Out:
#                     total_fragments  atac_pass_CR  atac_pass_entropy  \
# atac_barcodes
# AAACAAGCAAACATGT-1                4         False              False
# AAACAAGCAAACCAGC-1                1         False              False
#
#                     atac_pass_archr_TSS _2set_identified_by_atac_SC  \
# atac_barcodes
# AAACAAGCAAACATGT-1                False                        none
# AAACAAGCAAACCAGC-1                False                        none
#
#                    _2set_identified_by_atac_ST _3set_identified_by_atac  \
# atac_barcodes
# AAACAAGCAAACATGT-1                        none                     none
# AAACAAGCAAACCAGC-1                        none                     none
#
#                     Entropy DNA_debris  P_closed_state
# atac_barcodes
# AAACAAGCAAACATGT-1      NaN        NaN             NaN
# AAACAAGCAAACCAGC-1      NaN        NaN             NaN

# %% [markdown]
# ## Load

# %%
# Load union set cells 
Union_cell_subdir = os.path.join(entropy_dir, '_cell_calling_comparison')
Union_cell_info_file = os.path.join(Union_cell_subdir, 'Union_cell_3set_all_info.tsv')
union_cell_all_info = pd.read_csv(Union_cell_info_file, sep='\t', index_col=0)


union_cell_all_info['log_entropy'] = np.log2(union_cell_all_info['Entropy'])
union_cell_all_info['log_total_fragments'] = np.log1p(union_cell_all_info['total_fragments'])


union_cell_info = union_cell_all_info.loc[union_cell_all_info['_3set_identified_by_atac'] != 'none'].copy()

union_cell_all_info.shape, union_cell_info.shape
# Out:
# ((289009, 12), (2384, 12))

# %%
union_cell_info.head(2)
# Out:
#                     total_fragments  atac_pass_CR  atac_pass_entropy  \
# atac_barcodes
# AAACAAGCAAGTTAGT-1             2412          True               True
# AAACAAGCATTTCTTC-1             9030          True               True
#
#                     atac_pass_archr_TSS _2set_identified_by_atac_SC  \
# atac_barcodes
# AAACAAGCAAGTTAGT-1                 True                        both
# AAACAAGCATTTCTTC-1                 True                        both
#
#                    _2set_identified_by_atac_ST _3set_identified_by_atac  \
# atac_barcodes
# AAACAAGCAAGTTAGT-1                        both                   common
# AAACAAGCATTTCTTC-1                        both                   common
#
#                      Entropy DNA_debris  P_closed_state  log_entropy  \
# atac_barcodes
# AAACAAGCAAGTTAGT-1  0.218328         NO        0.965116    -2.195429
# AAACAAGCATTTCTTC-1  0.074451         NO        0.990949    -3.747572
#
#                     log_total_fragments
# atac_barcodes
# AAACAAGCAAGTTAGT-1             7.788626
# AAACAAGCATTTCTTC-1             9.108418

# %%
col_list = [ '_2set_identified_by_atac_SC', '_2set_identified_by_atac_ST', '_3set_identified_by_atac']
col_list += ['total_fragments']
for col in col_list:
    entropy_df[col] = entropy_df.index.map(union_cell_all_info[col]).fillna('none')

entropy_df['log_entropy'] = np.log2(entropy_df['Entropy'])
entropy_df['log_total_fragments'] = np.log1p(entropy_df['total_fragments'])
entropy_df.head(2)
# Out:
#                      Entropy  Entropy_open_region  Mp  mle_lambda  \
# AAGCCATAGCTAATAG-1  0.005725             1.069145  11    0.343957
# CACGGTAAGAATCACA-1  0.004039             1.910865  19    1.377521
#
#                     P0_open_region  P_closed_state DNA_debris  \
# AAGCCATAGCTAATAG-1        0.708959        0.999545         NO
# CACGGTAAGAATCACA-1        0.252203        0.999694         NO
#
#                              atac_bc _2set_identified_by_atac_SC  \
# AAGCCATAGCTAATAG-1  AAGCCATAGCTAATAG                        none
# CACGGTAAGAATCACA-1  CACGGTAAGAATCACA                        none
#
#                    _2set_identified_by_atac_ST _3set_identified_by_atac  \
# AAGCCATAGCTAATAG-1                        none                     none
# CACGGTAAGAATCACA-1                        none                     none
#
#                     total_fragments  log_entropy  log_total_fragments
# AAGCCATAGCTAATAG-1              636    -7.448404              6.45677
# CACGGTAAGAATCACA-1              501    -7.951883              6.21860
